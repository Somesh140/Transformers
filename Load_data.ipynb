# %% [markdown]
# <a href="https://colab.research.google.com/github/Somesh140/Transformers/blob/main/Load_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 21.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 21.9 MB/s eta 0:00:00
# ...

# %%
dataset_name = "Somesh140/stack-overflow-dataset"

from datasets import load_dataset

# %%
data = load_dataset(dataset_name)
# Out:
# ...
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/Somesh140___csv/Somesh140--stack-overflow-dataset-97b50d8c499a9458/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['pid', 'label', 'text'],
#         num_rows: 17536
#     })
#     test: Dataset({
#         features: ['pid', 'label', 'text'],
#         num_rows: 7464
#     })
# })

# %%
data["train"]
# Out:
# Dataset({
#     features: ['pid', 'label', 'text'],
#     num_rows: 17536
# })

# %%
data["train"][0]
# Out:
# {'pid': 4186249,
#  'label': 1,
# ...

# %%
import pandas as pd

# %%
pd.DataFrame(data["train"])
# Out:
#             pid  label                                               text
# 0       4186249      1  Searching and capturing a character using regu...
# 1         54312      0   <p>Yes, of course there is :-) object oriente...
# 2       7956164      0   <p>Try waiting for window's <code>load</code>...
# 3       3289313      0   <p>Assuming that's VB.Net, you need to escape...
# 4      10314039      0   <p>Usually when the add-to-cart button does n...
# ...         ...    ...                                                ...
# 17531  28223574      0  Try to move UIImageView in screen with touches...
# 17532  20632342      0   <p>Just change your for loop,</p> <pre><code>...
# 17533  21748244      0   <p>You might also consider using <a href="htt...
# 17534  40359412      0   <p>I used the (penultimate) code in Robert Mc...
# 17535  26905220      0   <p>Create a <code>List&lt;TextBox&gt;</code> ...
#
# [17536 rows x 3 columns]

# %%
load_dataset("xtreme","PAN-X.en")
# Out:
# ...
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset xtreme downloaded and prepared to /root/.cache/huggingface/datasets/xtreme/PAN-X.en/1.0.0/29f5d57a48779f37ccb75cb8708d1095448aad0713b425bdc1ff9a4a128a56e4. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'ner_tags', 'langs'],
#         num_rows: 20000
#     })
#     validation: Dataset({
#         features: ['tokens', 'ner_tags', 'langs'],
#         num_rows: 10000
#     })
#     test: Dataset({
#         features: ['tokens', 'ner_tags', 'langs'],
#         num_rows: 10000
#     })
# })
